# %%
# --- IMPORT TOOLS
# Pandas for working with DataFrames
import pandas as pd
# Import numpy for high-perfomance mathematical and numerical operations
import numpy as np
# Import Matplotlib for creating charts and visualizations
import matplotlib.pyplot as plt
# Import Seaborn for creating attractive statistical visualizations with less code
import seaborn as sns

# This makes plots appear directly inside the notebook
# %matplotlib inline

print("✅ Libreries loaded succesfully")
# Out:
# ✅ Libreries loaded succesfully

# %%
# --- LOAD THE DATASET
# pd.read_csv() reads the file and converts it into a DataFrame.
# encoding="latin-1" is required because the file contains special characters.
df = pd.read_csv("../data/raw/sales.csv", encoding="latin-1")

# .shape returns the number of rows and columns in the DataFrame.
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# The dataset has 9994 rows and 21 columns.

# %%
# --- PREVIEW THE DATASET
# .head(10) displays the first 10 rows of the DataFrame.
# This helps you quickly inspect the structure and contents of a new dataset.
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
# --- GENERAL INFORMATION
# .info views the "identity file" from the DataFrame
# - how many rows there is in total
# - how many columns exists
# - what kind of data type has every column(int,float,object)
# - how many values are null in every column
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
# --- BASIC STATISTICS
# .describe() generates descriptive statistics for all numerical columns,
# including count, mean, standard deviation, minimum, maximum,
# and the 25th, 50th (median), and 75th percentiles.
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# --- CHECK FOR MISSING VALUES
# .isnull() creates a boolean mask indicating missing values.
# .sum() counts the number of missing values in each column
# because True is treated as 1 and False as 0.
# The result shows the total number of NaN values per column.
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# --- CHECK FOR EXACT DUPLICATES
# .duplicated() marks True for each row that is an exact duplicate
# of a previous row.
# .sum() counts the total number of duplicated rows.
duplicates = df.duplicated().sum()

print(f"Duplicate rows found: {duplicates}")
# Out:
# Duplicate rows found: 0

# %%
# --- CHECK DATA TYPES
# .dtypes displays the data type of each column,
# such as int64, float64, object (text), etc.
# We are especially interested in the date column.
# It is currently stored as an "object" and will be converted
# to a proper datetime type in the next step.
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
# --- CHECK FOR HIDDEN MISSING VALUES

# Select all text columns (object and string dtypes).
# Including both types avoids compatibility warnings
text_columns = df.select_dtypes(include=["object", "string"]).columns

for col in text_columns:
    # .isin() checks whether a value matches one of the
    # common placeholders used to represent missing data.
    suspicious_values = df[col].isin(   
        ["N/A", "n/a", "-", "", " ", "NULL", "null"]
    ).sum()

    if suspicious_values > 0:
        print(
            f"Column '{col}': {suspicious_values} suspicious values found"
        )

print("Review completed ✅")
# Out:
# Review completed ✅

# %%
# --- CONVERT TEXT DATES TO DATETIME

# pd.to_datetime() converts a string such as "2023-11-15"
# into a proper datetime object.
# Once a column has a datetime type, pandas can extract
# components such as year, month, day, and more.
# detect the date format.

df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# Verify that the conversion was successful.
print(df[["Order Date", "Ship Date"]].dtypes)
# Out:
# Order Date    datetime64[us]
# Ship Date     datetime64[us]
# dtype: object

# %%
# --- LOAD THE CLEAN DATASET
# Always work from the processed/ folder, never from raw/
# parse_dates tells pandas to convert these columns to datetime while loading
# This way, we don't need to perform the conversion again

df = pd.read_csv(
    "../data/processed/ventas_limpio.csv",
    parse_dates=["Order Date", "Ship Date"]
)

print(f"Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Dataset loaded: 9994 rows, 23 columns

# %%
# --- SALES TREND BY YEAR
# .groupby() groups rows that share the same value in a column
# It works like SQL's "GROUP BY"
# .agg() defines what to calculate for each group:
#   - Sales: total sales amount
#   - Order ID: count the number of orders
# .reset_index() converts the result into a regular DataFrame
annual_sales = df.groupby("Order Year").agg(
    total_sales=("Sales", "sum"),
    number_of_orders=("Order ID", "count")
).reset_index()

print(annual_sales)
# Out:
#    Order Year  total_sales  number_of_orders
# 0        2014  484247.4981              1993
# 1        2015  470532.5090              2102
# 2        2016  609205.5980              2587
# 3        2017  733215.2552              3312

# %%
# --- PROFIT BY CATEGORY 
# Same pattern: groupby + agg
# This time, we group by Category and calculate the total Profit
# .sort_values() sorts the result from highest to lowest (ascending=False)

profit_by_category = df.groupby("Category").agg(
    Total_Profit=("Profit", "sum"),
    Total_Sales=("Sales", "sum")
).reset_index().sort_values("Total_Profit", ascending=False)

print(profit_by_category)
# Out:
#           Category  Total_Profit  Total_Sales
# 2       Technology   145454.9481  836154.0330
# 1  Office Supplies   122490.8008  719047.0320
# 0        Furniture    18451.2728  741999.7953

# %%
# --- SALES BY REGION
# Group the data by Region
# Calculate the total Sales and total Profit for each region
# Sort the results from highest to lowest total sales

sales_by_region = df.groupby("Region").agg(
    Total_Sales=("Sales", "sum"),
    Total_Profit=("Profit", "sum")
).reset_index().sort_values("Total_Sales", ascending=False)

print(sales_by_region)
# Out:
#     Region  Total_Sales  Total_Profit
# 3     West  725457.8245   108418.4489
# 1     East  678781.2400    91522.7800
# 0  Central  501239.8908    39706.3625
# 2    South  391721.9050    46749.4303

# %%
# --- DISCOUNT VS PROFIT
# pd.cut() splits the Discount values into ranges (bins)
# For example: [0–20%], [20–40%], [40–60%], [60–80%]
# This allows us to compare discount groups with their average profit

df["Discount Range"] = pd.cut(
    df["Discount"],
    bins=[0, 0.2, 0.4, 0.6, 0.8],  # The boundaries of each range
    labels=["0-20%", "20-40%", "40-60%", "60-80%"],  # Labels for each range
    include_lowest=True  # Include the value 0 in the first range
)

discount_vs_profit = df.groupby("Discount Range", observed=True).agg(
    Average_Profit=("Profit", "mean"),
    Number_of_Transactions=("Order ID", "count")
).reset_index()

print(discount_vs_profit)
# Out:
#   Discount Range  Average_Profit  Number_of_Transactions
# 0          0-20%       49.037679                    8601
# 1         20-40%      -77.864055                     460
# 2         40-60%     -134.624160                     215
# 3         60-80%      -98.348741                     718

# %%
# --- GLOBAL VISUAL CONFIGURATION
# Seaborn includes built-in themes that automatically improve plot aesthetics.
# "whitegrid" uses a white background with gray grid lines — ideal for data visualization.
sns.set_theme(style="whitegrid")

# Set a standard figure size for all plots.
# figsize = (width, height) in inches.
plt.rcParams["figure.figsize"] = (10, 5)

print("✅ Visual configuration is ready")
# Out:
# ✅ Visual configuration is ready

# %%
# --- ANNUAL SALES CHART (BAR CHART) 
# plt.subplots() creates a new figure and axes for the chart.
fig, ax = plt.subplots(figsize=(8, 5))

# sns.barplot() draws a bar chart.
# x represents the category, while y represents the numerical value.
# palette defines the colors — "Blues_d" is a blue color palette.
sns.barplot(
    data=annual_sales,
    x="Order Year",
    y="total_sales",
    hue="Order Year",  # Adds color grouping by year.
    palette="Blues_d",
    legend=False,      # Hides the legend since it's redundant.
    ax=ax
)

# Set the chart title and axis labels.
# Without these, the chart would be difficult to interpret.
ax.set_title("Total Sales by Year", fontsize=14, fontweight="bold")
ax.set_xlabel("Year")
ax.set_ylabel("Sales (USD)")

# Format the y-axis values.
# Converts numbers like 200000 into "$200,000" for better readability.
ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda x, _: f"${x:,.0f}")
)

plt.tight_layout()  # Prevents labels and titles from being cut off.
plt.savefig("../outputs/graphics/annual_sales.png", dpi=150)  # Saves the figure.
plt.show()

# %%
# --- PROFIT BY CATEGORY CHART 
fig, ax = plt.subplots(figsize=(8, 5))

# Colors help communicate meaning:
# Green = positive, blue = neutral, red = negative or low values.
colors = ["#2ecc71", "#3498db", "#e74c3c"]

sns.barplot(
    data=profit_by_category,
    x="Category",
    y="Total_Sales",
    hue="Category",
    palette=colors,
    ax=ax
)

# Set the chart title and axis labels.
ax.set_title("Total Profit by Category", fontsize=14, fontweight="bold")
ax.set_xlabel("Category")
ax.set_ylabel("Profit (USD)")

# Format the y-axis values as currency.
ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda x, _: f"${x:,.0f}")
)

# Draw a horizontal line at zero to make it easier
# to identify positive and negative values.
ax.axhline(0, color="black", linewidth=0.8, linestyle="--")

plt.tight_layout()  # Prevents labels and titles from being cut off.
plt.savefig("../outputs/graphics/profit_by_category.png", dpi=150)  # Saves the figure.
plt.show()

# %%
# --- AVERAGE PROFIT BY DISCOUNT RANGE CHART 
# This is the most important chart in the analysis—it highlights the key finding.
fig, ax = plt.subplots(figsize=(8, 5))

# Use colors that reinforce the message:
# red represents the discount ranges where money is lost.
discount_colors = ["#2ecc71", "#f39c12", "#e67e22", "#e74c3c"]

sns.barplot(
    data=discount_vs_profit,
    x="Discount Range",
    y="Average_Profit",
    hue="Discount Range",
    palette=discount_colors,
    ax=ax
)

# Set the chart title and axis labels.
ax.set_title("Average Profit by Discount Range", fontsize=14, fontweight="bold")
ax.set_xlabel("Discount Range")
ax.set_ylabel("Average Profit (USD)")

# Format the y-axis values as currency.
ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda x, _: f"${x:,.0f}")
)

# Draw a horizontal line at zero to clearly distinguish
# positive profits from negative profits.
ax.axhline(0, color="black", linewidth=0.8, linestyle="--")

plt.tight_layout()  # Prevents labels and titles from being cut off.
plt.savefig("../outputs/graphics/discount_vs_profit.png", dpi=150)  # Saves the figure.
plt.show()

# %%
# --- TOTAL SALES BY REGION CHART 
fig, ax = plt.subplots(figsize=(8, 5))

sns.barplot(
    data=sales_by_region.sort_values("Total_Sales", ascending=False),
    x="Region",
    y="Total_Sales",
    hue="Region",
    palette="Greens_d",
    ax=ax
)

# Set the chart title and axis labels.
ax.set_title("Total Sales by Region", fontsize=14, fontweight="bold")
ax.set_xlabel("Region")
ax.set_ylabel("Sales (USD)")

# Format the y-axis values as currency.
ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda x, _: f"${x:,.0f}")
)

plt.tight_layout()  # Prevents labels and titles from being cut off.
plt.savefig("../outputs/graphics/sales_by_region.png", dpi=150)  # Saves the figure.
plt.show()
